# %% [markdown]
# # Welcome To The Practice Notebook
# ---

# %% [markdown]
# Importing the pandas library

# %%
import pandas as pd

# %% [markdown]
# Import the json Imdb Dataset

# %%
data = pd.read_json('movies_dataset.json')
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color      James Cameron                   723.0     178.0  760505847.0
# 1  Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color         Sam Mendes                   602.0     148.0  200074175.0
# 3  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4    NaN        Doug Walker                     NaN       NaN          NaN
#
#                             genres        star_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title  \
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# ...

# %% [markdown]
# Answer to the following Analytical questions:
#
# Question 1: Which country has gained the highest average IMdb Score according to our data? <br>
# Use a bar chart to visualize your results

# %%
ax = data.groupby('country')['imdb_score'].mean().plot.bar(figsize = (18,8))
ax.set_title('Country Average Imdb score')
ax.set_xlabel('Country')
ax.set_ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# Question 2: How many `colored` and `Black&White` movies do we have in our dataset?

# %%
# Write your code here, below is the code i wrote before the video
#data_q4 = [data[data.color == "Color"].color.count(), data[data.color == "Black and White"].color.count() ]
#data_q4
data.groupby("color").size()
#issue with the code that i wrote before is that it only shows black and white and colored, also you dont know which value is black&white and which one is colored, and this way is also easier and less complex
# Out:
# color
# Black and White     209
# Color              4815
# dtype: int64

# %% [markdown]
# Question 3: Which movies of `Christopher Nolan` has the highest IMdb Score? <br>
# Use a barchart to visualize the results

# %%
# Write your code here
CN = data[data.director_name == 'Christopher Nolan'] #no need for the extra variable can just do .plot.bar() at the end
ax = CN.plot.bar(x = 'movie_title', y = 'imdb_score', title = 'Christopher Nolan Movies')
ax.set_xlabel('Movies')
ax.set_ylabel('Imdb Score')
# Out:
# Text(0, 0.5, 'Imdb Score')

# %% [markdown]
# Question 4: Use a line chart to visualize how many movies have been produced in `USA` from `2010` to `2015`.

# %%
# Write your code here
usa = data[data.country == "USA"]
usa_year=usa.groupby('title_year').size()
year = [2011, 2012, 2013, 2014]
# can mix all the lines above into
# data[(data.country == 'USA') & (data.title_year > 2010) & (data.title_year < 2015)].groupby("title_year").size.plot()
#can also add .shape to get shape or .plot() to plot it for a line chart
#also you can have multiple comparison for a list just need to put each comparsion in a () with &
movies = usa_year[year].plot(title = 'USA Movies Between 2010 and 2015')
movies.set_xlabel("Year")
movies.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
